# %% [markdown]
# ![Northumbri University](./img/uni.png)
# <b>Dissertation</b>
# <H1> Kf7029 – MSc Computer Science and Digital Technologies Project </H1>

# %% [markdown]
# <h2 style='
# background-color: #f0f0f0;
# width: 100%;
# padding:10px;
# text-align:center;
# font-family: Arial, Helvetica;'>
# <b>Project :</b> AI technology improve health care services </h2>

# %% [markdown]
# <h3> <b>Student Name:</b>
# : Soumya Reddy
# </h3>
#
# <h3> <b>Student ID:</b>
# : W190000
# </h3>
#
# ---
#
# <h4> <b>Module tutor:</b>
# : aaaa
# </h4>
#
# <h4> <b>Supervisor name of your :</b>
# : bbb
# </h4>

# %% [markdown]
# <hr style='
#            background-color:#23A455;
#            opacity:40%;
#            border-top: 1px solid #6EC1E4;
#            height: 2px;
#            border: 1px;
#            border-bottom: 1px solid #54595F;'>

# %% [markdown]
# # [1.] Project requirements
#
# THIS SECTION ILLUSTRATE LIST OF ANALYSIS REQUIREMENTS

# %% [markdown]
# 1. Download and install anaconda: https://docs.anaconda.com/anaconda/install/windows/

# %% [markdown]
# 2. Downlaod Disease Symptom Prediction dataset: https://www.kaggle.com/itachi9604/disease-symptom-description-dataset

# %% [markdown]
# # [2.] Setup and import library
#
# THIS SECTION INSTALL PACKAGES AND IMPORT LIBRARY

# %% [markdown]
# ## 2.1 Setup library

# %%
# pip install numpy
# pip install pandas

# %% [markdown]
# Execute above installation statements only once. No need to execute again and again

# %% [markdown]
# ## 2.1 Import library
# THE BELLOW STATEMENT IMPORT NECESSARY LIBRARY

# %%
# USED FOR LINEAR ALGEBRA
import numpy as np

# USED FOR PANDAS DATA AND DATASET PROCESSING (WITH CSV DATA)
import pandas as pd

# USED FOR PLOTING GRAPH
import matplotlib.pyplot as plt# for Plotting graphs
import seaborn as sns

# IMPORT LIBRARY
from sklearn.model_selection import train_test_split

# IGNORE THE WARNINGS
import warnings
warnings.filterwarnings('ignore')

# FOR MODE TIME 
from datetime import datetime

# %% [markdown]
# # [3.] Loading data files
#
# THIS SECTION LOAD CSV (DATASET) FILES.

# %%
# DATASET FILENAME
# 1.) SYMPTOMS WITH ITS EFFECTS ON THE BODY PER TWO DAYS
symptoms = "./dataset/Symptom-severity.csv"

# 2.) DISEASE
Disease = "./dataset/dataset.csv"

# 3.) DISEASE AND ITS DESCRIPTION
Disease_desc = "./dataset/symptom_Description.csv"

# 4.) DISEASE AND THE PRECAUTIONS TO TAKE
Disease_preca = "./dataset/symptom_precaution.csv"

# %%
# READING THE CSV DATA FILES
# 1.) SYMPTOMS WITH ITS EFFECT ON BODY PER TWO DAYS
pd_symptoms=pd.read_csv(symptoms,names=['Symptom','weight'], header=0)

# 2.) DISEASE
pd_Disease=pd.read_csv(Disease,names=['Disease','Symptom_1','Symptom_2','Symptom_3','Symptom_4','Symptom_5','Symptom_6','Symptom_7','Symptom_8','Symptom_9','Symptom_10','Symptom_11','Symptom_12','Symptom_13','Symptom_14','Symptom_15','Symptom_16','Symptom_17'], header=0)

# 3.) DISEASE AND ITS DESCRIPTION
pd_Disease_desc=pd.read_csv(Disease_desc,names=['Disease','Description'], header=0)

# 4.) DISEASE AND THE PRECAUTIONS TO TAKE
pd_Disease_preca=pd.read_csv(Disease_preca,names=['Disease','Precaution_1','Precaution_2','Precaution_3','Precaution_4'], header=0)

# %% [markdown]
# # [4.] analyzing the Dataset
# THIS SECTION DISPLAY SAMPLE DATA, COUNT, DATA TYPES, COLUMNS, NUMBER OF ROWS, AND OTHER CALCULATION

# %% [markdown]
# ## 4.1  Symptoms with its effect on body per two day.

# %%
# DISPLAY DATASET
pd_symptoms.head()
# Out:
#                 Symptom  weight
# 0               itching       1
# 1             skin_rash       3
# 2  nodal_skin_eruptions       4
# 3   continuous_sneezing       4
# 4             shivering       5

# %%
# VIEW THE DATASET STRUCUTRE
pd_symptoms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Symptom  133 non-null    object
#  1   weight   133 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
# SHOW TOTAL ROWS AND COLUMNS IN THE DATASET
print('(Rows,Columns) :', pd_symptoms.shape)
# Out:
# (Rows,Columns) : (133, 2)

# %%
# DATASET COUNT, MEAN, STD, MIN, MAX AND PERCENT
pd_symptoms.describe()
# Out:
#            weight
# count  133.000000
# mean     4.225564
# std      1.323543
# min      1.000000
# 25%      3.000000
# 50%      4.000000
# 75%      5.000000
# max      7.000000

# %% [markdown]
# ## 4.2 Disease

# %%
# 2.) DISPLAY DISEASE
pd_Disease.head()
# Out:
#             Disease   Symptom_1              Symptom_2              Symptom_3  \
# 0  Fungal infection     itching              skin_rash   nodal_skin_eruptions
# 1  Fungal infection   skin_rash   nodal_skin_eruptions    dischromic _patches
# 2  Fungal infection     itching   nodal_skin_eruptions    dischromic _patches
# 3  Fungal infection     itching              skin_rash    dischromic _patches
# 4  Fungal infection     itching              skin_rash   nodal_skin_eruptions
#
#               Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0   dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                   NaN       NaN       NaN       NaN       NaN       NaN
# 2                   NaN       NaN       NaN       NaN       NaN       NaN
# 3                   NaN       NaN       NaN       NaN       NaN       NaN
# 4                   NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
# VIEW DATASET STRUCTURE
pd_Disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Disease     4920 non-null   object
#  1   Symptom_1   4920 non-null   object
#  2   Symptom_2   4920 non-null   object
#  3   Symptom_3   4920 non-null   object
#  4   Symptom_4   4572 non-null   object
#  5   Symptom_5   3714 non-null   object
#  6   Symptom_6   2934 non-null   object
#  7   Symptom_7   2268 non-null   object
#  8   Symptom_8   1944 non-null   object
#  9   Symptom_9   1692 non-null   object
#  10  Symptom_10  1512 non-null   object
#  11  Symptom_11  1194 non-null   object
#  12  Symptom_12  744 non-null    object
#  13  Symptom_13  504 non-null    object
#  14  Symptom_14  306 non-null    object
#  15  Symptom_15  240 non-null    object
#  16  Symptom_16  192 non-null    object
#  17  Symptom_17  72 non-null     object
# dtypes: object(18)
# memory usage: 692.0+ KB

# %%
# TO SHOW TOTAL ROWS AND COLUMNS IN THE DISEASE DATASET
print('(Rows,Columns) :', pd_Disease.shape)
# Out:
# (Rows,Columns) : (4920, 18)

# %%
# DATASET COUNT, MEAN, STD, MIN, MAX AND PERCENT
pd_Disease.describe()
# Out:
#              Disease  Symptom_1  Symptom_2 Symptom_3    Symptom_4  Symptom_5  \
# count           4920       4920       4920      4920         4572       3714
# unique            41         34         48        54           50         38
# top     Tuberculosis   vomiting   vomiting   fatigue   high_fever   headache
# freq             120        822        870       726          378        348
#
#        Symptom_6        Symptom_7        Symptom_8           Symptom_9  \
# count       2934             2268             1944                1692
# unique        32               26               21                  22
# top       nausea   abdominal_pain   abdominal_pain   yellowing_of_eyes
# freq         390              264              276                 228
#
#                 Symptom_10     Symptom_11 Symptom_12              Symptom_13  \
# count                 1512           1194        744                     504
# ...

# %%
# DISPLAY NULL OR MISSING VALUES
pd_Disease.isnull().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1206
# Symptom_6     1986
# Symptom_7     2652
# Symptom_8     2976
# Symptom_9     3228
# Symptom_10    3408
# Symptom_11    3726
# Symptom_12    4176
# Symptom_13    4416
# Symptom_14    4614
# Symptom_15    4680
# Symptom_16    4728
# Symptom_17    4848
# dtype: int64

# %% [markdown]
# ## 4.3 Disease and its description

# %%
# 3.) DISPLAY DATASET
pd_Disease_desc.head()
# Out:
#           Disease                                        Description
# 0   Drug Reaction  An adverse drug reaction (ADR) is an injury ca...
# 1         Malaria  An infectious disease caused by protozoan para...
# 2         Allergy  An allergy is an immune system response to a f...
# 3  Hypothyroidism  Hypothyroidism, also called underactive thyroi...
# 4       Psoriasis  Psoriasis is a common skin disorder that forms...

# %%
# VIEW DATASET STRUCTURE
pd_Disease_desc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Disease      41 non-null     object
#  1   Description  41 non-null     object
# dtypes: object(2)
# memory usage: 784.0+ bytes

# %%
# TO SHOW TOTAL ROWS AND COLUMNS IN DATASET
print('(Rows,Columns) :', pd_Disease_desc.shape)
# Out:
# (Rows,Columns) : (41, 2)

# %%
# DATASET COUNT, MEAN, STD, MIN, MAX AND PERCENT
pd_Disease_desc.describe()
# Out:
#                  Disease                                        Description
# count                 41                                                 41
# unique                41                                                 41
# top     Fungal infection  A vein that has enlarged and twisted, often ap...
# freq                   1                                                  1

# %%
# DISPLAY NULL OR MISSING VALUES
pd_Disease_desc.isnull().sum()
# Out:
# Disease        0
# Description    0
# dtype: int64

# %% [markdown]
# ## 4.4 Disease and the precautions to take

# %%
# DISPLAY DATASET
pd_Disease_preca.head()
# Out:
#           Disease                      Precaution_1  \
# 0   Drug Reaction                   stop irritation
# 1         Malaria          Consult nearest hospital
# 2         Allergy                    apply calamine
# 3  Hypothyroidism                     reduce stress
# 4       Psoriasis  wash hands with warm soapy water
#
#                    Precaution_2        Precaution_3  \
# 0      consult nearest hospital    stop taking drug
# 1               avoid oily food  avoid non veg food
# 2       cover area with bandage                 NaN
# 3                      exercise         eat healthy
# 4  stop bleeding using pressure      consult doctor
#
#                   Precaution_4
# 0                    follow up
# 1           keep mosquitos out
# 2  use ice to compress itching
# 3             get proper sleep
# 4                   salt baths

# %%
# VIEW DATASET STRUCTURE
pd_Disease_preca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Disease       41 non-null     object
#  1   Precaution_1  41 non-null     object
#  2   Precaution_2  41 non-null     object
#  3   Precaution_3  40 non-null     object
#  4   Precaution_4  40 non-null     object
# dtypes: object(5)
# memory usage: 1.7+ KB

# %%
# TO SHOW TOTAL ROWS AND COLUMNS IN DATASET
print('(Rows,Columns) :', pd_Disease_preca.shape)
# Out:
# (Rows,Columns) : (41, 5)

# %%
# DATASET COUNT, MEAN, STD, MIN, MAX AND PERCENT
pd_Disease_preca.describe()
# Out:
#                  Disease            Precaution_1 Precaution_2    Precaution_3  \
# count                 41                      41           41              40
# unique                41                      32           34              30
# top     Fungal infection  avoid fatty spicy food     exercise  consult doctor
# freq                   1                       3            3               6
#
#        Precaution_4
# count            40
# unique           24
# top       follow up
# freq              6

# %%
# DISPLAY NULL OR MISSING VALUES
pd_Disease_preca.isnull().sum()
# Out:
# Disease         0
# Precaution_1    0
# Precaution_2    0
# Precaution_3    1
# Precaution_4    1
# dtype: int64

# %% [markdown]
# # [5.] Adding COVID -19 Disease
# THIS SECTION ADD CORONA VIRUS VARIANT DISEASE, SYMPTOMS, DESCRITION, AND PRECAUTIONS

# %% [markdown]
# ## 5.1 Disease

# %%
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19', 'Symptom_1':'high_temperature', 'Symptom_2':'continuous_cough', 'Symptom_3':'headache', 'Symptom_4':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_5':np.nan, 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19', 'Symptom_1':'high_temperature', 'Symptom_2':'continuous_cough', 'Symptom_3':'headache', 'Symptom_4':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_5':np.nan, 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19', 'Symptom_1':'high_temperature', 'Symptom_2':'fever', 'Symptom_3':'continuous_cough', 'Symptom_4':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_5':np.nan, 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 delta', 'Symptom_1':'headache', 'Symptom_2':'sore_throat', 'Symptom_3':'runny_nose', 'Symptom_4':'fever', 'Symptom_5':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 delta', 'Symptom_1':'headache', 'Symptom_2':'headache', 'Symptom_3':'runny_nose', 'Symptom_4':'fever', 'Symptom_5':'fatigue', 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 delta', 'Symptom_1':'runny_nose', 'Symptom_2':'sore_throat', 'Symptom_3':'sore_throat', 'Symptom_4':'fever', 'Symptom_5':'headache', 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 alpha', 'Symptom_1':'fatigue', 'Symptom_2':'headache', 'Symptom_3':'sore_throat', 'Symptom_4':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_5':np.nan, 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 alpha', 'Symptom_1':'fatigue', 'Symptom_2':'headache', 'Symptom_3':'fever', 'Symptom_4':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_5':np.nan, 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 alpha', 'Symptom_1':'fatigue', 'Symptom_2':'headache', 'Symptom_3':'sore_throat', 'Symptom_4':np.nan, 'Symptom_5':np.nan, 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 alpha', 'Symptom_1':'Fever_or_chills', 'Symptom_2':'cough', 'Symptom_3':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_4':'shortness_of_breath_or_difficulty_breathing', 'Symptom_5':'fatigue', 'Symptom_6':'muscle_or_body_aches', 'Symptom_7':'headache', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 alpha', 'Symptom_1':'Fever_or_chills', 'Symptom_2':'cough', 'Symptom_3':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_4':'shortness_of_breath_or_difficulty_breathing', 'Symptom_5':'fatigue', 'Symptom_6':'headache', 'Symptom_7':'cough', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 alpha', 'Symptom_1':'Fever_or_chills', 'Symptom_2':'cough', 'Symptom_3':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_4':'headache', 'Symptom_5':'sore_throat', 'Symptom_6':'continuous_cough', 'Symptom_7':'cough', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 omicron', 'Symptom_1':'dry_coughs', 'Symptom_2':'fever', 'Symptom_3':'night_sweats', 'Symptom_4':'a_lot_of_body_pains', 'Symptom_5':'headache', 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 omicron', 'Symptom_1':'dry_coughs', 'Symptom_2':'fever', 'Symptom_3':'night_sweats', 'Symptom_4':'night_sweats', 'Symptom_5':np.nan, 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 omicron', 'Symptom_1':'dry_coughs', 'Symptom_2':'fever', 'Symptom_3':'night_sweats', 'Symptom_4':np.nan, 'Symptom_5':np.nan, 'Symptom_6':np.nan, 'Symptom_7':np.nan, 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 omicron', 'Symptom_1':'cough', 'Symptom_2':'nausea_or_vomiting', 'Symptom_3':'diarrhoea', 'Symptom_4':'continuous_cough', 'Symptom_5':'sore_throat', 'Symptom_6':'pain_in_the_lower_back_and_lower_limbs', 'Symptom_7':'headache', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 omicron', 'Symptom_1':'pain_in_the_lower_back_and_lower_limbs', 'Symptom_2':np.nan, 'Symptom_3':'diarrhoea', 'Symptom_4':'diarrhea', 'Symptom_5':'muscle_or_body_aches', 'Symptom_6':'loose_motion', 'Symptom_7':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 omicron', 'Symptom_1':'pain_in_the_lower_back_and_lower_limbs', 'Symptom_2':np.nan, 'Symptom_3':'sore_throat', 'Symptom_4':np.nan, 'Symptom_5':np.nan, 'Symptom_6':'loose_motion', 'Symptom_7':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 omicron', 'Symptom_1':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_2':'continuous_cough', 'Symptom_3':'sore_throat', 'Symptom_4':'cough', 'Symptom_5':'headache', 'Symptom_6':'loose_motion', 'Symptom_7':'congestion_or_runny_nose', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 beta', 'Symptom_1':'Fever_or_chills', 'Symptom_2':'cough', 'Symptom_3':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_4':'headache', 'Symptom_5':'nausea_or_vomiting', 'Symptom_6':'congestion_or_runny_nose', 'Symptom_7':'cough', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 beta', 'Symptom_1':'Fever_or_chills', 'Symptom_2':'cough', 'Symptom_3':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_4':'headache', 'Symptom_5':'diarrhea', 'Symptom_6':np.nan, 'Symptom_7':'cough', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 beta', 'Symptom_1':'Fever_or_chills', 'Symptom_2':'cough', 'Symptom_3':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_4':'headache', 'Symptom_5':'congestion', 'Symptom_6':'muscle_or_body_aches', 'Symptom_7':'cough', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 gamma', 'Symptom_1':'Fever_or_chills', 'Symptom_2':'cough', 'Symptom_3':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_4':'congestion_or_runny_nose', 'Symptom_5':'headache', 'Symptom_6':np.nan, 'Symptom_7':'cough', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 gamma', 'Symptom_1':'Fever_or_chills', 'Symptom_2':'cough', 'Symptom_3':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_4':'congestion_or_runny_nose', 'Symptom_5':'headache', 'Symptom_6':'congestion', 'Symptom_7':'cough', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 gamma', 'Symptom_1':'Fever_or_chills', 'Symptom_2':'cough', 'Symptom_3':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_4':'diarrhea', 'Symptom_5':'muscle_or_body_aches', 'Symptom_6':np.nan, 'Symptom_7':'cough', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)
pd_Disease = pd.concat([pd.DataFrame({'Disease':'COVID-19 gamma', 'Symptom_1':'Fever_or_chills', 'Symptom_2':'cough', 'Symptom_3':'loss_or_change_to_sense_of_smell_or_taste', 'Symptom_4':'sore_throat', 'Symptom_5':'high_temperature', 'Symptom_6':np.nan, 'Symptom_7':'runny_nose', 'Symptom_8':np.nan},index =[0]), pd_Disease]).reset_index(drop = True)

# %%
pd_Disease.head()
# Out:
#           Disease        Symptom_1 Symptom_2  \
# 0  COVID-19 gamma  Fever_or_chills     cough
# 1  COVID-19 gamma  Fever_or_chills     cough
# 2  COVID-19 gamma  Fever_or_chills     cough
# 3  COVID-19 gamma  Fever_or_chills     cough
# 4   COVID-19 beta  Fever_or_chills     cough
#
#                                    Symptom_3                 Symptom_4  \
# 0  loss_or_change_to_sense_of_smell_or_taste               sore_throat
# 1  loss_or_change_to_sense_of_smell_or_taste                  diarrhea
# 2  loss_or_change_to_sense_of_smell_or_taste  congestion_or_runny_nose
# 3  loss_or_change_to_sense_of_smell_or_taste  congestion_or_runny_nose
# 4  loss_or_change_to_sense_of_smell_or_taste                  headache
#
#               Symptom_5             Symptom_6   Symptom_7 Symptom_8 Symptom_9  \
# 0      high_temperature                   NaN  runny_nose       NaN       NaN
# 1  muscle_or_body_aches                   NaN       cough       NaN       NaN
# ...

# %% [markdown]
# ## 5.1 Disease description

# %%
pd_Disease_desc = pd.concat([pd.DataFrame({'Disease':np.nan, 'Description':np.nan},index =[0]), pd_Disease_desc]).reset_index(drop = True)
pd_Disease_desc = pd.concat([pd.DataFrame({'Disease':'COVID-19', 'Description':'Corona virus disease (COVID-19) is disease. Patients infected by the SARS-CoV-2 virus.'},index =[0]), pd_Disease_desc]).reset_index(drop = True)
pd_Disease_desc = pd.concat([pd.DataFrame({'Disease':'COVID-19 alpha', 'Description':'It is a variant of SARS-CoV-2 virus (COVID-19). (Date founded : November 2019)'},index =[0]), pd_Disease_desc]).reset_index(drop = True)
pd_Disease_desc = pd.concat([pd.DataFrame({'Disease':'COVID-19 gamma', 'Description':'It is a variant of SARS-CoV-2 virus (COVID-19).(Date founded : November 2019)'},index =[0]), pd_Disease_desc]).reset_index(drop = True)
pd_Disease_desc = pd.concat([pd.DataFrame({'Disease':'COVID-19 beta', 'Description':'It is a variant of SARS-CoV-2 virus (COVID-19).(Date founded : end of the year 2020)'},index =[0]), pd_Disease_desc]).reset_index(drop = True)
pd_Disease_desc = pd.concat([pd.DataFrame({'Disease':'COVID-19 delta', 'Description':'It is a variant of SARS-CoV-2 virus (COVID-19).(Date founded : 31 May 2021)'},index =[0]), pd_Disease_desc]).reset_index(drop = True)

# %%
pd_Disease_desc.head()
# Out:
#           Disease                                        Description
# 0  COVID-19 delta  It is a variant of SARS-CoV-2 virus (COVID-19)...
# 1   COVID-19 beta  It is a variant of SARS-CoV-2 virus (COVID-19)...
# 2  COVID-19 gamma  It is a variant of SARS-CoV-2 virus (COVID-19)...
# 3  COVID-19 alpha  It is a variant of SARS-CoV-2 virus (COVID-19)...
# 4        COVID-19  Corona virus disease (COVID-19) is disease. Pa...

# %% [markdown]
# ## 5.1 Symptoms and weights

# %%
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'continuous_cough', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'cough', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'diarrhea', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'dry_coughs', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'Fever_or_chills', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'high_temperature', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'loss_or_change_to_sense_of_smell_or_taste', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'muscle_or_body_aches', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'nausea_or_vomiting', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'shortness_of_breath_or_difficulty_breathing', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'sore_throat', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'tiredness_or_body_pain', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'pain_in_the_lower_back_and_lower_limbs', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'loose_motion', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'fever', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'night_sweats', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'a_lot_of_body_pains', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)
pd_symptoms = pd.concat([pd.DataFrame({'Symptom':'congestion_or_runny_nose', 'weight':8},index =[0]), pd_symptoms]).reset_index(drop = True)

# %%
pd_symptoms.head()
# Out:
#                     Symptom  weight
# 0  congestion_or_runny_nose       8
# 1       a_lot_of_body_pains       8
# 2              night_sweats       8
# 3                     fever       8
# 4              loose_motion       8

# %% [markdown]
# ## 5.1 Precautions

# %%
pd_Disease_preca = pd.concat([pd.DataFrame({'Disease':'COVID-19','Precaution_1':'Wear a mask','Precaution_2':' Clean your hands','Precaution_3':' Maintain safe distance','Precaution_4':' Get vaccinated.'},index =[0]), pd_Disease_preca]).reset_index(drop = True)
pd_Disease_preca = pd.concat([pd.DataFrame({'Disease':'COVID-19 alpha','Precaution_1':'Wear a mask','Precaution_2':' Clean your hands','Precaution_3':' Maintain safe distance','Precaution_4':' Get vaccinated.'},index =[0]), pd_Disease_preca]).reset_index(drop = True)
pd_Disease_preca = pd.concat([pd.DataFrame({'Disease':'COVID-19 gamma','Precaution_1':'Wear a mask','Precaution_2':' Clean your hands','Precaution_3':' Maintain safe distance','Precaution_4':' Get vaccinated.'},index =[0]), pd_Disease_preca]).reset_index(drop = True)
pd_Disease_preca = pd.concat([pd.DataFrame({'Disease':'COVID-19 beta','Precaution_1':'Wear a mask','Precaution_2':' Clean your hands','Precaution_3':' Maintain safe distance','Precaution_4':' Get vaccinated.'},index =[0]), pd_Disease_preca]).reset_index(drop = True)
pd_Disease_preca = pd.concat([pd.DataFrame({'Disease':'COVID-19 delta','Precaution_1':'Wear a mask','Precaution_2':' Clean your hands','Precaution_3':' Maintain safe distance','Precaution_4':' Get vaccinated.'},index =[0]), pd_Disease_preca]).reset_index(drop = True)
pd_Disease_preca = pd.concat([pd.DataFrame({'Disease':'COVID-19 omicron','Precaution_1':'Wear a mask','Precaution_2':' Clean your hands','Precaution_3':' Maintain safe distance','Precaution_4':' Get vaccinated.'},index =[0]), pd_Disease_preca]).reset_index(drop = True)

# %%
pd_Disease_preca.head()
# Out:
#             Disease Precaution_1       Precaution_2             Precaution_3  \
# 0  COVID-19 omicron  Wear a mask   Clean your hands   Maintain safe distance
# 1    COVID-19 delta  Wear a mask   Clean your hands   Maintain safe distance
# 2     COVID-19 beta  Wear a mask   Clean your hands   Maintain safe distance
# 3    COVID-19 gamma  Wear a mask   Clean your hands   Maintain safe distance
# 4    COVID-19 alpha  Wear a mask   Clean your hands   Maintain safe distance
#
#        Precaution_4
# 0   Get vaccinated.
# 1   Get vaccinated.
# 2   Get vaccinated.
# 3   Get vaccinated.
# 4   Get vaccinated.

# %%
pd_Disease_preca = pd.concat([pd.DataFrame({'Disease':np.nan,'Precaution_1':'Wear a mask','Precaution_2':' Clean your hands','Precaution_3':' Maintain safe distance','Precaution_4':' Get vaccinated.'},index =[0]), pd_Disease_preca]).reset_index(drop = True)

# %% [markdown]
# # [6.] Processing data
# THIS SECTION PROCESS DATA AND CREATE TRAIN AND TEST SET SO IT CAN USE FOR MODEL PROCESSING.

# %%
# MERGE DISEASE, DISEASE DESCRIPTION AND PRECAUTION DATASET
pd_model=pd.merge(pd_Disease, pd_Disease_desc, on = 'Disease')
pd_model = pd.merge(pd_model , pd_Disease_preca, on = 'Disease')

# %%
pd_model.isna().sum()
# Out:
# Disease            0
# Symptom_1          0
# Symptom_2          0
# Symptom_3          0
# Symptom_4        349
# Symptom_5       1134
# Symptom_6       1759
# Symptom_7       2421
# Symptom_8       2755
# Symptom_9       3007
# Symptom_10      3139
# Symptom_11      3385
# Symptom_12      3835
# Symptom_13      4075
# Symptom_14      4273
# Symptom_15      4339
# Symptom_16      4387
# Symptom_17      4507
# Description        0
# Precaution_1       0
# Precaution_2       0
# Precaution_3     120
# Precaution_4     120
# dtype: int64

# %%
# CREATE AXIS-X AS SYMPTOMS
#Xaxis = pd_model[['Disease','Symptom_1','Symptom_2','Symptom_3','Symptom_4','Symptom_5','Symptom_6','Symptom_7','Symptom_8','Symptom_9','Symptom_10','Symptom_11','Symptom_12','Symptom_13','Symptom_14','Symptom_15','Symptom_16','Symptom_17']]
Xaxis = pd_model[['Disease','Symptom_1','Symptom_2','Symptom_3','Symptom_4','Symptom_5','Symptom_6']]

# %%
Xaxis
# Out:
#              Disease        Symptom_1    Symptom_2  \
# 0     COVID-19 gamma  Fever_or_chills        cough
# 1     COVID-19 gamma  Fever_or_chills        cough
# 2     COVID-19 gamma  Fever_or_chills        cough
# 3     COVID-19 gamma  Fever_or_chills        cough
# 4      COVID-19 beta  Fever_or_chills        cough
# ...              ...              ...          ...
# 4574        Impetigo        skin_rash   high_fever
# 4575        Impetigo        skin_rash   high_fever
# 4576        Impetigo        skin_rash   high_fever
# 4577        Impetigo        skin_rash   high_fever
# 4578        Impetigo        skin_rash   high_fever
#
#                                       Symptom_3                 Symptom_4  \
# 0     loss_or_change_to_sense_of_smell_or_taste               sore_throat
# 1     loss_or_change_to_sense_of_smell_or_taste                  diarrhea
# 2     loss_or_change_to_sense_of_smell_or_taste  congestion_or_runny_nose
# ...

# %%
# Copy columns
lstColumns = Xaxis.columns
main_data = Xaxis[lstColumns].values.flatten()

# strip and reshape
tmpSymp = pd.Series(main_data)
tmpSymp = tmpSymp.str.strip()
tmpSymp = tmpSymp.values.reshape(Xaxis.shape)

# Fill zero value for empty cells
Xaxis = pd.DataFrame(tmpSymp, columns=Xaxis.columns)
Xaxis = Xaxis.fillna(0)

# %%
Xaxis
# Out:
#              Disease        Symptom_1   Symptom_2  \
# 0     COVID-19 gamma  Fever_or_chills       cough
# 1     COVID-19 gamma  Fever_or_chills       cough
# 2     COVID-19 gamma  Fever_or_chills       cough
# 3     COVID-19 gamma  Fever_or_chills       cough
# 4      COVID-19 beta  Fever_or_chills       cough
# ...              ...              ...         ...
# 4574        Impetigo        skin_rash  high_fever
# 4575        Impetigo        skin_rash  high_fever
# 4576        Impetigo        skin_rash  high_fever
# 4577        Impetigo        skin_rash  high_fever
# 4578        Impetigo        skin_rash  high_fever
#
#                                       Symptom_3                 Symptom_4  \
# 0     loss_or_change_to_sense_of_smell_or_taste               sore_throat
# 1     loss_or_change_to_sense_of_smell_or_taste                  diarrhea
# 2     loss_or_change_to_sense_of_smell_or_taste  congestion_or_runny_nose
# ...

# %%
# SELECT UNIQUE SYMPTOM
symptoms = pd_symptoms['Symptom'].unique()

# EXECUTE LOOP AND FILL THE VALUE FOR EACH SYMPTOMS
arrray_vals = Xaxis.values
for i in range(len(symptoms)):
    arrray_vals[arrray_vals == symptoms[i]] = pd_symptoms[pd_symptoms['Symptom'] == symptoms[i]]['weight'].values[0]
    
Xaxis = pd.DataFrame(arrray_vals, columns=lstColumns)
Xaxis.head()
# Out:
#           Disease Symptom_1 Symptom_2 Symptom_3 Symptom_4 Symptom_5 Symptom_6
# 0  COVID-19 gamma         8         8         8         8         8         0
# 1  COVID-19 gamma         8         8         8         8         8         0
# 2  COVID-19 gamma         8         8         8         8         3         5
# 3  COVID-19 gamma         8         8         8         8         3         0
# 4   COVID-19 beta         8         8         8         3         5         8

# %%
not_weighted=['dischromic _patches','foul_smell_of urine','spotting_ urination']
for w in not_weighted:
    Xaxis = Xaxis.replace(w, 0)
Xaxis.head()
# Out:
#           Disease  Symptom_1  Symptom_2  Symptom_3  Symptom_4  Symptom_5  \
# 0  COVID-19 gamma          8          8          8          8          8
# 1  COVID-19 gamma          8          8          8          8          8
# 2  COVID-19 gamma          8          8          8          8          3
# 3  COVID-19 gamma          8          8          8          8          3
# 4   COVID-19 beta          8          8          8          3          5
#
#    Symptom_6
# 0          0
# 1          0
# 2          5
# 3          0
# 4          8

# %%
(Xaxis[lstColumns] == 0).all()
Xaxis['Disease'].value_counts()
Xaxis['Disease'].unique()
dsdata = Xaxis.iloc[:,1:].values
Yaxis = Xaxis['Disease'].values

# %%
Yaxis
# Out:
# array(['COVID-19 gamma', 'COVID-19 gamma', 'COVID-19 gamma', ...,
#        'Impetigo', 'Impetigo', 'Impetigo'], dtype=object)

# %%
train_x, test_x, train_y, test_y = train_test_split(dsdata, Yaxis, shuffle=True, train_size = 0.8, random_state = 42)

# %%
print ('size of X and Y : ', main_data.shape,  Yaxis.shape)
# Out:
# size of X and Y :  (32053,) (4579,)

# %%
print ('size of Train x and y : ', train_x.shape,  train_y.shape)
# Out:
# size of Train x and y :  (3663, 6) (3663,)

# %%
print ('size of Test x and y : ', test_x.shape,  test_y.shape)
# Out:
# size of Test x and y :  (916, 6) (916,)

# %%
# Display trin-x
train_x
# Out:
# array([[5, 3, 4, 2, 0, 0],
#        [3, 5, 3, 5, 4, 4],
#        [1, 3, 5, 0, 0, 0],
#        ...,
#        [3, 4, 8, 7, 4, 3],
#        [3, 3, 2, 5, 2, 0],
#        [5, 3, 4, 6, 0, 0]], dtype=int64)

# %%
# Display trin-x
train_y
# Out:
# array(['Paralysis (brain hemorrhage)', 'Migraine', 'Drug Reaction', ...,
#        'Pneumonia', 'Osteoarthristis', 'Gastroenteritis'], dtype=object)

# %%
test_x
# Out:
# array([[3, 2, 2, 2, 0, 0],
#        [3, 5, 6, 4, 4, 0],
#        [3, 3, 2, 5, 2, 0],
#        ...,
#        [5, 3, 5, 6, 4, 4],
#        [3, 5, 4, 3, 8, 7],
#        [3, 5, 3, 4, 5, 4]], dtype=int64)

# %%
test_y
# Out:
# array(['Acne', '(vertigo) Paroymsal  Positional Vertigo',
#        'Osteoarthristis', 'Hypothyroidism', 'Arthritis', 'Allergy',
#        'Hepatitis D', 'Fungal infection', 'Drug Reaction',
#        'Fungal infection', 'Hepatitis B', 'Hepatitis E',
#        'Osteoarthristis', 'Chronic cholestasis', 'Common Cold', 'Typhoid',
#        'Fungal infection', 'Hyperthyroidism', 'Malaria',
#        'Paralysis (brain hemorrhage)', 'Common Cold', 'Hypothyroidism',
#        'Allergy', 'Varicose veins', 'Jaundice', 'AIDS', 'Drug Reaction',
#        'Tuberculosis', 'Arthritis', 'Hypoglycemia', 'Hepatitis E',
#        'Migraine', 'Varicose veins', 'GERD', 'Gastroenteritis',
#        'Hepatitis B', 'Osteoarthristis', 'Chronic cholestasis',
#        'Hepatitis D', 'Jaundice', 'Typhoid', 'Hepatitis B',
#        'Heart attack', 'Hyperthyroidism', 'Dengue', 'Common Cold',
#        'Paralysis (brain hemorrhage)', 'Hepatitis E', 'Impetigo',
#        'Varicose veins', 'Migraine', 'Osteoarthristis',
# ...

# %% [markdown]
# # [6.] Apply Machine Learning (ML) algorithms
# THIS SECTION APPLY MOST USEFUL MAHCINE LEARNING ALRORITHMS GIVEN BELLOW
# - 1) RANDOM FOREST (RF)
# - 2) K NEAREST NEIGHBOR (KNN)
# - 3) SUPPORT VECTOR MACHINE (SVM)
# - 4) Custom SUPPORT VECTOR MACHINE (Custom SVM)
# - 5) EXTREME GRADIENT BOOSTING (XGBOOST)
# - 6) LOGISTIC REGRESSION (LR)
# - 7) DECISION TREE (DT)
# - 8) NAIVE BAYES MODEL (NBM)

# %% [markdown]
# ## FUNCTION DEFINITION

# %%
# IMPORT LIBRARY
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import f1_score, classification_report, accuracy_score,precision_score, confusion_matrix,recall_score

# %%
# TO STORE MODEL SCORE DATA
model_scores = {}

# %%
"""
THE FUNCTION FIND THE MODEL STANDARD DEVIATION, MEAN ACCURACY, ACCURACY, PRECISION, RECALL, F1-SCORE, ETC
"""
def measurement(model, model_info, predict_y):
        
    # FIND THE MODEL ACCURACY
    model_accuracy=accuracy_score(test_y,predict_y)
            
    # FIND THE MODEL PRECISION
    model_precision=precision_score(test_y,predict_y,average='micro')
        
    # FIND THE MODEL RECALL
    model_recall=recall_score(test_y,predict_y,average='micro')
        
    # FIND THE MODEL F1-SCORE
    model_f1_score=f1_score(test_y,predict_y,average='micro')
    
    
    # USING KFold FIND MODEL MEAN ACCURACY AND DEVIATION
    kfold = KFold(shuffle=True,n_splits=10,random_state=42)    
    model_train =cross_val_score(model, train_x, train_y, cv=kfold, scoring='accuracy')
    pd.DataFrame(model_train,columns=['Scores'])
    
    # FIND MEAN ACCURACY
    Mean_accuracy=model_train.mean()    
        
    # FIND STANDARD DEVIATION
    std=model_train.std()
    
    # DISPLAY EACH VALUES
    print('Standard Deviation:',std)
    print('Mean accuracy:',Mean_accuracy)
    print('Accuracy: ',model_accuracy)
    print('precision: ',model_precision)
    print('recall: ',model_recall)
    print('F1-Score',model_f1_score)
    
    # SAVE INTO DATAFRAME
    model_scores[f"{model_info} "] = [model_accuracy, model_precision, model_recall,model_f1_score,Mean_accuracy,std]

# %%
test_y.shape
# Out:
# (916,)

# %%
"""
FUNCTION TO DISPLAY HEATMAP OF CONFUSION MATRIX OF EACH DISEASE
"""
def conf_matrix_graph(model_info,predicted):
    # PREPARE CONFESION MATRIX
    
    conf_matrix_rf = confusion_matrix(test_y, predicted)
    indices=conf_matrix_rf.shape[0]
    conf_matrix_rf = pd.DataFrame(conf_matrix_rf, 
                                  index=pd_model['Disease'].unique()[:indices], 
                                  columns=pd_model['Disease'].unique()[:indices])
    #[:42]
    # SHOW HEATMAP GRAPH
    plt.figure(figsize = (16,8))
    sns.heatmap(conf_matrix_rf, cmap="YlGnBu")
    
    # SET GRAPH LABEL
    plt.xlabel('Disease')
    plt.title(model_info)
    plt.ylabel('Disease')
    
    # RETURN THE MATRIX
    return conf_matrix_rf

# %% [markdown]
# ## 6.1 	Random forest  (RF)

# %%
# START TIME 
model_start_time=datetime.now()

# %%
# IMPORT LIBRARY
from sklearn.ensemble import RandomForestClassifier

# CREATE THE MODEL
model_rf = RandomForestClassifier()

# FIT THE MODEL
model_rf.fit(train_x,train_y)
# Out:
# RandomForestClassifier()

# %%
# PREDICT VALUES
predict_rf = model_rf.predict(test_x)

# CALCULATE THE MODEL TEST VALUE 
# 1.) ACCURACY
# 2.) PRECISION
# 3.) RECALL 
# 4.) F1-SCORE
# 5.) MEAN ACCURACY
# 6.) STANDARD DEVIATION
measurement(model_rf,'Random forest',predict_rf)

# DISPLAY THE CONFESION MATRIX
conf_matrix=conf_matrix_graph('Random forest',predict_rf)
# Out:
# Standard Deviation: 0.005329953370094833
# Mean accuracy: 0.9863477315704055
# Accuracy:  0.9847161572052402
# precision:  0.9847161572052402
# recall:  0.9847161572052402
# F1-Score 0.9847161572052402

# %%
# TOTAL TIME
print ('Time: ',(datetime.now()-model_start_time))
# Out:
# Time:  0:00:07.660819

# %% [markdown]
# ## 6.2 K Nearest Neighbor (KNN)

# %%
# START TIME 
model_start_time=datetime.now()

# %%
# IMPORT LIBRARY
from sklearn.neighbors import KNeighborsClassifier

# CREATE THE KNN MODEL
model_knn = KNeighborsClassifier(n_neighbors=1)

# FIT THE MODEL DATA
model_knn.fit(train_x, train_y)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
# PREDICT THE VALUES
predict_knn = model_knn.predict(test_x)

# CALCULATE THE MODEL TEST VALUE 
# 1.) ACCURACY
# 2.) PRECISION
# 3.) RECALL 
# 4.) F1-SCORE
# 5.) MEAN ACCURACY
# 6.) STANDARD DEVIATION
measurement(model_knn,'KNN',predict_knn)

# DISPLAY CONFESION MATRIX
conf_matrix=conf_matrix_graph('KNN',predict_knn)
# Out:
# Standard Deviation: 0.011784642231599215
# Mean accuracy: 0.9797977993180567
# Accuracy:  0.980349344978166
# precision:  0.980349344978166
# recall:  0.980349344978166
# F1-Score 0.980349344978166

# %%
# TOTAL TIME
print ('Time: ',(datetime.now()-model_start_time))
# Out:
# Time:  0:00:03.888123

# %% [markdown]
# ## 6.3 Support Vector Machine (SVM)

# %%
# START TIME 
model_start_time=datetime.now()

# %%
# IMPORT LIBRARY
from sklearn.svm import SVC

# CREATE SVM MODEL
model_svc=SVC()

# FIT THE MODEL DATA
model_SVM=model_svc.fit(train_x,train_y)

# PREDICT TEST DATA USING 
predict_SVM=model_SVM.predict(test_x)

# %%
# CALCULATE THE MODEL TEST VALUE 
# 1.) ACCURACY
# 2.) PRECISION
# 3.) RECALL 
# 4.) F1-SCORE
# 5.) MEAN ACCURACY
# 6.) STANDARD DEVIATION
measurement(model_SVM,'SVM',predict_SVM)

# DISPLAY THE CONFESION MATRIX
conf_matrix=conf_matrix_graph('SVM',predict_SVM)
# Out:
# Standard Deviation: 0.010491584894018167
# Mean accuracy: 0.9530411995056657
# Accuracy:  0.9541484716157205
# precision:  0.9541484716157205
# recall:  0.9541484716157205
# F1-Score 0.9541484716157205

# %%
# TOTAL TIME
print ('Time: ',(datetime.now()-model_start_time))
# Out:
# Time:  0:00:04.332607

# %% [markdown]
# ## 6.4 Custom Support Vector Machine (Custom SVM)

# %%
# START TIME 
model_start_time=datetime.now()

# %%
# CREATE MODIFIED SVM MODEL
custom_SVM = SVC(gamma=0.3,C=0.02, kernel='poly')

# FIT THE MODEL DATA
custom_SVM.fit(train_x, train_y)

# PREDICT THE DATA
custom_SVM_predict = custom_SVM.predict(test_x)

# %%
# CALCULATE THE MODEL TEST VALUE 
# 1.) ACCURACY
# 2.) PRECISION
# 3.) RECALL 
# 4.) F1-SCORE
# 5.) MEAN ACCURACY
# 6.) STANDARD DEVIATION
measurement(custom_SVM,'Modified SVM',custom_SVM_predict)

# DISPLAY THE CONFESION MATRIX
conf_matrix=conf_matrix_graph('Modified SVM',custom_SVM_predict)
# Out:
# Standard Deviation: 0.006492428386472488
# Mean accuracy: 0.9847091317877934
# Accuracy:  0.9847161572052402
# precision:  0.9847161572052402
# recall:  0.9847161572052402
# F1-Score 0.9847161572052402

# %%
# TOTAL TIME
print ('Time: ',(datetime.now()-model_start_time))
# Out:
# Time:  0:00:03.188203

# %% [markdown]
# ## 6.5 XGBoost (eXtreme Gradient Boosting)

# %%
# START TIME 
model_start_time=datetime.now()

# %%
# IMPORT LIBRARY
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

# CREATE MODEL
model_xgboost = XGBClassifier( eval_metric="logloss",objective="b")
model_xgboost = GridSearchCV(model_xgboost, 
                             {'objective':
                              ["rank:pairwise", "reg:squarederror", "binary:logistic", "reg:gamma"]},
                             cv=5)

# %%
# FIT THE MODEL
model_xgboost.fit(train_x, train_y)

# PREDICT THE DATA
model_xgboost_predict=model_xgboost.predict(test_x)

# %%
# CALCULATE THE MODEL TEST VALUE 
# 1.) ACCURACY
# 2.) PRECISION
# 3.) RECALL 
# 4.) F1-SCORE
# 5.) MEAN ACCURACY
# 6.) STANDARD DEVIATION
measurement(model_xgboost,'XGBoost',model_xgboost_predict)

# DISPLAY THE CONFESION MATRIX
conf_matrix=conf_matrix_graph('XGBoost',model_xgboost_predict)
# Out:
# Standard Deviation: 0.006240904801103347
# Mean accuracy: 0.985528059439258
# Accuracy:  0.9847161572052402
# precision:  0.9847161572052402
# recall:  0.9847161572052402
# F1-Score 0.9847161572052402

# %%
# TOTAL TIME
print ('Time: ',(datetime.now()-model_start_time))
# Out:
# Time:  0:11:37.647754

# %% [markdown]
# ## 6.6 Logistic Regression (LR)

# %%
# START TIME 
model_start_time=datetime.now()

# %%
# IMPORT LIBRARY
from sklearn.linear_model import LogisticRegression

# %%
# CREATE THE MODEL
model_LR = LogisticRegression()

# FIT THE MODEL
model_LR.fit(train_x, train_y)

# PREDICT TEST X
model_LR_predict = model_LR.predict(test_x)

# %%
# CALCULATE THE MODEL TEST VALUE 
# 1.) ACCURACY
# 2.) PRECISION
# 3.) RECALL 
# 4.) F1-SCORE
# 5.) MEAN ACCURACY
# 6.) STANDARD DEVIATION
measurement(model_LR,'Logistic Regression',model_LR_predict)

# DISPLAY THE CONFESION MATRIX
conf_matrix=conf_matrix_graph('Logistic Regression',model_LR_predict)
# Out:
# Standard Deviation: 0.015171947271595399
# Mean accuracy: 0.8528483792677297
# Accuracy:  0.8526200873362445
# precision:  0.8526200873362445
# recall:  0.8526200873362445
# F1-Score 0.8526200873362445

# %%
# TOTAL TIME
print ('Time: ',(datetime.now()-model_start_time))
# Out:
# Time:  0:00:15.341500

# %% [markdown]
# ## 6.7 Decision Tree (DT)

# %%
# START TIME 
model_start_time=datetime.now()

# %%
# IMPORT LIBRARY
from sklearn.tree import DecisionTreeClassifier

# %%
# CREATE THE MODEL
model_DT =DecisionTreeClassifier(random_state=42,criterion='gini',max_depth=13)

# FIT THE MODEL
model_DT.fit(train_x, train_y)

# PREDICT DATA
model_DT_predict=model_DT.predict(test_x)

# %%
# CALCULATE THE MODEL TEST VALUE 
# 1.) ACCURACY
# 2.) PRECISION
# 3.) RECALL 
# 4.) F1-SCORE
# 5.) MEAN ACCURACY
# 6.) STANDARD DEVIATION
measurement(model_DT,'Decision Tree',model_DT_predict)

# DISPLAY THE CONFESION MATRIX
conf_matrix=conf_matrix_graph('Decision Tree',model_DT_predict)
# Out:
# Standard Deviation: 0.007871393547793117
# Mean accuracy: 0.9806144935304717
# Accuracy:  0.9814410480349345
# precision:  0.9814410480349345
# recall:  0.9814410480349345
# F1-Score 0.9814410480349345

# %%
# TOTAL TIME
print ('Time: ',(datetime.now()-model_start_time))
# Out:
# Time:  0:00:02.814790

# %% [markdown]
# ## 6.8 Naive Bayes Model (NBM)

# %%
# START TIME 
model_start_time=datetime.now()

# %%
# IMPORT LIBRARY
from sklearn.naive_bayes import GaussianNB

# %%
# CREATE THE MODEL
model_NBM = GaussianNB()

# FIT THE MODEL
model_NBM.fit(train_x, train_y)

# PREDICT THE VALUE
model_NBM_predict=model_NBM.predict(test_x)

# %%
# CALCULATE THE MODEL TEST VALUE 
# 1.) ACCURACY
# 2.) PRECISION
# 3.) RECALL 
# 4.) F1-SCORE
# 5.) MEAN ACCURACY
# 6.) STANDARD DEVIATION
measurement(model_NBM,'Naive Bayes Model (NBM)',model_NBM_predict)

# DISPLAY THE CONFESION MATRIX
conf_matrix=conf_matrix_graph('Naive Bayes Model (NBM)',model_NBM_predict)
# Out:
# Standard Deviation: 0.014361903599298353
# Mean accuracy: 0.8061754589717246
# Accuracy:  0.787117903930131
# precision:  0.787117903930131
# recall:  0.787117903930131
# F1-Score 0.787117903930131

# %%
# TOTAL TIME
print ('Time: ',(datetime.now()-model_start_time))
# Out:
# Time:  0:00:02.575222

# %% [markdown]
# # Anaylsis

# %%
# DISPLAY MODEL SCORE

# COLUMNS
cols=['Accuracy','precision','recall','f1_score','Mean Accuracy','Standard Deviation']

# Models
models=['Random forest','KNN','SVM','Hybrid SVM','xgboost','Logistic Regression','Decision Tree','Naive Bayes Model (NBM)']

# CREATE DATA FRAME 
PD_SCORE = pd.DataFrame.from_dict(model_scores, orient='index', columns=cols)

PD_SCORE
# Out:
#                           Accuracy  precision    recall  f1_score  \
# Random forest             0.984716   0.984716  0.984716  0.984716
# KNN                       0.980349   0.980349  0.980349  0.980349
# SVM                       0.954148   0.954148  0.954148  0.954148
# Modified SVM              0.984716   0.984716  0.984716  0.984716
# XGBoost                   0.984716   0.984716  0.984716  0.984716
# Logistic Regression       0.852620   0.852620  0.852620  0.852620
# Decision Tree             0.981441   0.981441  0.981441  0.981441
# Naive Bayes Model (NBM)   0.787118   0.787118  0.787118  0.787118
#
#                           Mean Accuracy  Standard Deviation
# Random forest                  0.986348            0.005330
# KNN                            0.979798            0.011785
# SVM                            0.953041            0.010492
# Modified SVM                   0.984709            0.006492
# XGBoost                        0.985528            0.006241
# ...

# %%
models
# Out:
# ['Random forest',
#  'KNN',
#  'SVM',
#  'Hybrid SVM',
#  'xgboost',
#  'Logistic Regression',
#  'Decision Tree',
#  'Naive Bayes Model (NBM)']

# %%
w=0.25
for name in cols:
    plt.figure(figsize=(5,4))
    plt.bar(models, PD_SCORE[name],  label = name,width = w)
    plt.title(f"Comparision of {name}",)
    plt.xlabel("Models")
    plt.xticks(models, rotation=90)
    plt.ylabel("Value")
    plt.legend()
    plt.show()

# %%
for name in cols:
    # DISPLAY LINE CHART
    fig, ax = plt.subplots(figsize=(4, 4))
    sns.lineplot(
        y=name,
        x=np.arange(len(models)),     
        ax=ax,
        data=PD_SCORE,     
        label=name)

    ax.set_xticklabels(models)
    plt.xticks(np.arange(len(PD_SCORE)), rotation=90)
    ax.set(title=f"Comparision of {name}",xlabel="Algorithms",ylabel="Value")

# %% [markdown]
# # Prediction

# %%
"""
Method - find list of the precaution for the patient disease
"""
def suggest_Precaution(patient_disease):
    tmp=pd_Disease_preca[pd_Disease_preca['Disease']==patient_disease]
    print('\nPrecaution:')    
    for index, row in tmp.iterrows(): 
        print(f" [1]",row['Precaution_1'])
        print(f" [2]",row['Precaution_2'])
        print(f" [2]",row['Precaution_3'])
        print(f" [2]",row['Precaution_4'])
    return tmp

# %%
"""
Method - find list of the symptoms for the patient disease
"""

def disease_symptoms(patient_disease):
    tmp_Symptoms=[]
    
    # Find other symptoms for the disease
    tmp=pd_model[pd_model['Disease']==patient_disease][['Symptom_1','Symptom_2','Symptom_3','Symptom_4','Symptom_5','Symptom_6','Symptom_7','Symptom_8','Symptom_9','Symptom_10','Symptom_11','Symptom_12','Symptom_13','Symptom_14','Symptom_15','Symptom_16','Symptom_17']]
    for index, row in tmp.iterrows():
        for j in range(18):
            if(j>0) :
                col='Symptom_'+str(j)
                symp=str(row[col]).strip()
                if(symp!='nan'):
                    tmp_Symptoms.append(symp)
    
    # Select unique values
    tmp_Symptoms=np.unique(tmp_Symptoms)    
    return tmp_Symptoms

# %%
"""
Method - Predict disease for the given patient symptoms
"""
def predict_disease(model,symptoms):
        
    # CREATE COPY OF PATIENT PYMPTOMS
    user_symptoms=symptoms.copy()
    
    
    # SEARCH WEIGHT FOR THE SYMPTOM
    dataSymptom = np.array(pd_symptoms["Symptom"])
    dataweight = np.array(pd_symptoms["weight"])    
    
    #for j in range(17):
    for j in range(6):
        if (j <len(symptoms)):
            for k in range(len(dataSymptom)):
                if symptoms[j]==dataSymptom[k]:
                    symptoms[j]=dataweight[k]
        else:
            symptoms.append(0)
    # SHOW SYMPTOMS WEIGHT    
    print ('Patient symptoms:',user_symptoms)
    print('\nPatient symptoms weight:',symptoms)    
    
    # PREDICT DISEASE
    symptoms = [symptoms]      
    predicted_disease = model.predict(symptoms)

    # SHOW PREDICTED DISEASE
    print('\nDisease : ',predicted_disease)        
    
    
    # SHOW ANY OTHER SYMPTOMS FOR THE DISEASE
    disease_Symptoms=disease_symptoms(predicted_disease[0])    
    print ('\nDisease symptoms (all):',disease_Symptoms,'\n')
    
    # REMOVE USER SYMTOMS FOR DISEASE SYMPTOMS
    print ('\nMore symptoms:')
    for s in disease_Symptoms:            
        if(s in user_symptoms) or s=='nan':      
            tmp=0
        else:
            print(' > ', s) 
            
    # DISEASE PRECAUTIONS
    suggest_Precaution(predicted_disease[0])

# %%
symptoms=['Fever_or_chills','cough','loss_or_change_to_sense_of_smell_or_taste','headache','sore_throat','continuous_cough']
predict_disease(model_xgboost,symptoms)
# Out:
# Patient symptoms: ['Fever_or_chills', 'cough', 'loss_or_change_to_sense_of_smell_or_taste', 'headache', 'sore_throat', 'continuous_cough']
#
# Patient symptoms weight: [8, 8, 8, 3, 8, 8]
#
# Disease :  ['COVID-19 beta']
#
# Disease symptoms (all): ['Fever_or_chills' 'congestion' 'congestion_or_runny_nose' 'cough'
#  'diarrhea' 'headache' 'loss_or_change_to_sense_of_smell_or_taste'
#  'muscle_or_body_aches' 'nausea_or_vomiting']
#
#
# More symptoms:
#  >  congestion
#  >  congestion_or_runny_nose
#  >  diarrhea
#  >  muscle_or_body_aches
#  >  nausea_or_vomiting
#
# Precaution:
#  [1] Wear a mask
#  [2]  Clean your hands
#  [2]  Maintain safe distance
#  [2]  Get vaccinated.

# %%
symptoms=['dry_coughs','fever','night_sweats','a_lot_of_body_pains','headache']
predict_disease(model_xgboost,symptoms)
# Out:
# Patient symptoms: ['dry_coughs', 'fever', 'night_sweats', 'a_lot_of_body_pains', 'headache']
#
# Patient symptoms weight: [8, 8, 8, 8, 3, 0]
#
# Disease :  ['COVID-19 gamma']
#
# Disease symptoms (all): ['Fever_or_chills' 'congestion' 'congestion_or_runny_nose' 'cough'
#  'diarrhea' 'headache' 'high_temperature'
#  'loss_or_change_to_sense_of_smell_or_taste' 'muscle_or_body_aches'
#  'runny_nose' 'sore_throat']
#
#
# More symptoms:
#  >  Fever_or_chills
#  >  congestion
#  >  congestion_or_runny_nose
#  >  cough
#  >  diarrhea
#  >  high_temperature
#  >  loss_or_change_to_sense_of_smell_or_taste
#  >  muscle_or_body_aches
#  >  runny_nose
#  >  sore_throat
#
# Precaution:
#  [1] Wear a mask
#  [2]  Clean your hands
#  [2]  Maintain safe distance
#  [2]  Get vaccinated.

# %%
symptoms=['headache','headache','runny_nose','fever','fatigue']
predict_disease(model_xgboost,symptoms)
# Out:
# Patient symptoms: ['headache', 'headache', 'runny_nose', 'fever', 'fatigue']
#
# Patient symptoms weight: [3, 3, 5, 8, 4, 0]
#
# Disease :  ['GERD']
#
# Disease symptoms (all): ['acidity' 'chest_pain' 'cough' 'stomach_pain' 'ulcers_on_tongue'
#  'vomiting']
#
#
# More symptoms:
#  >  acidity
#  >  chest_pain
#  >  cough
#  >  stomach_pain
#  >  ulcers_on_tongue
#  >  vomiting
#
# Precaution:
#  [1] avoid fatty spicy food
#  [2] avoid lying down after eating
#  [2] maintain healthy weight
#  [2] exercise

# %%
symptoms=['acidity', 'skin_rash',  'shivering', 'vomiting']
predict_disease(model_xgboost,symptoms)
# Out:
# Patient symptoms: ['acidity', 'skin_rash', 'shivering', 'vomiting']
#
# Patient symptoms weight: [3, 3, 5, 5, 0, 0]
#
# Disease :  ['Drug Reaction']
#
# Disease symptoms (all): ['burning_micturition' 'itching' 'skin_rash' 'spotting_ urination'
#  'stomach_pain']
#
#
# More symptoms:
#  >  burning_micturition
#  >  itching
#  >  spotting_ urination
#  >  stomach_pain
#
# Precaution:
#  [1] stop irritation
#  [2] consult nearest hospital
#  [2] stop taking drug
#  [2] follow up

# %%
symptoms=['stomach_pain',  'vomiting',  'chest_pain']
predict_disease(model_xgboost,symptoms)
# Out:
# Patient symptoms: ['stomach_pain', 'vomiting', 'chest_pain']
#
# Patient symptoms weight: [5, 5, 7, 0, 0, 0]
#
# Disease :  ['Heart attack']
#
# Disease symptoms (all): ['breathlessness' 'chest_pain' 'sweating' 'vomiting']
#
#
# More symptoms:
#  >  breathlessness
#  >  sweating
#
# Precaution:
#  [1] call ambulance
#  [2] chew or swallow asprin
#  [2] keep calm
#  [2] nan

# %%
symptoms=['fatigue', 'weight_loss', 'restlessness', 'lethargy', 'irregular_sugar_level']
predict_disease(model_xgboost,symptoms)
# Out:
# Patient symptoms: ['fatigue', 'weight_loss', 'restlessness', 'lethargy', 'irregular_sugar_level']
#
# Patient symptoms weight: [4, 3, 5, 2, 5, 0]
#
# Disease :  ['Hepatitis C']
#
# Disease symptoms (all): ['family_history' 'fatigue' 'loss_of_appetite' 'nausea'
#  'yellowing_of_eyes' 'yellowish_skin']
#
#
# More symptoms:
#  >  family_history
#  >  loss_of_appetite
#  >  nausea
#  >  yellowing_of_eyes
#  >  yellowish_skin
#
# Precaution:
#  [1] Consult nearest hospital
#  [2] vaccination
#  [2] eat healthy
#  [2] medication

# %%
symptoms=['acidity', 'chills', 'skin_rash', 'continuous_sneezing', 'shivering', 'vomiting']
predict_disease(model_xgboost,symptoms)
# Out:
# Patient symptoms: ['acidity', 'chills', 'skin_rash', 'continuous_sneezing', 'shivering', 'vomiting']
#
# Patient symptoms weight: [3, 3, 3, 4, 5, 5]
#
# Disease :  ['Dengue']
#
# Disease symptoms (all): ['back_pain' 'chills' 'fatigue' 'headache' 'high_fever' 'joint_pain'
#  'loss_of_appetite' 'malaise' 'muscle_pain' 'nausea'
#  'pain_behind_the_eyes' 'red_spots_over_body' 'skin_rash' 'vomiting']
#
#
# More symptoms:
#  >  back_pain
#  >  fatigue
#  >  headache
#  >  high_fever
#  >  joint_pain
#  >  loss_of_appetite
#  >  malaise
#  >  muscle_pain
#  >  nausea
#  >  pain_behind_the_eyes
#  >  red_spots_over_body
#
# Precaution:
#  [1] drink papaya leaf juice
#  [2] avoid fatty spicy food
#  [2] keep mosquitos away
#  [2] keep hydrated

# %%
symptoms=['high_temperature','continuous_cough','headache','loss_or_change_to_sense_of_smell_or_taste']
predict_disease(model_xgboost,symptoms)
# Out:
# Patient symptoms: ['high_temperature', 'headache', 'loss_or_change_to_sense_of_smell_or_taste']
#
# Patient symptoms weight: [8, 3, 8, 0, 0, 0]
#
# Disease :  ['Urinary tract infection']
#
# Disease symptoms (all): ['bladder_discomfort' 'burning_micturition' 'continuous_feel_of_urine'
#  'foul_smell_of urine']
#
#
# More symptoms:
#  >  bladder_discomfort
#  >  burning_micturition
#  >  continuous_feel_of_urine
#  >  foul_smell_of urine
#
# Precaution:
#  [1] drink plenty of water
#  [2] increase vitamin c intake
#  [2] drink cranberry juice
#  [2] take probiotics

# %%
symptoms=['high_temperature','fever','a_lot_of_body_pains','headache']
predict_disease(model_xgboost,symptoms)
# Out:
# Patient symptoms: ['high_temperature', 'fever', 'a_lot_of_body_pains', 'headache']
#
# Patient symptoms weight: [8, 8, 8, 3, 0, 0]
#
# Disease :  ['COVID-19 beta']
#
# Disease symptoms (all): ['Fever_or_chills' 'congestion' 'congestion_or_runny_nose' 'cough'
#  'diarrhea' 'headache' 'loss_or_change_to_sense_of_smell_or_taste'
#  'muscle_or_body_aches' 'nausea_or_vomiting']
#
#
# More symptoms:
#  >  Fever_or_chills
#  >  congestion
#  >  congestion_or_runny_nose
#  >  cough
#  >  diarrhea
#  >  loss_or_change_to_sense_of_smell_or_taste
#  >  muscle_or_body_aches
#  >  nausea_or_vomiting
#
# Precaution:
#  [1] Wear a mask
#  [2]  Clean your hands
#  [2]  Maintain safe distance
#  [2]  Get vaccinated.
